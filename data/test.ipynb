# %%
import csv

filePath = "C:/Users/thoma/cs257/cs257/data/games1-1000.csv"
outPath = "C:/Users/thoma/cs257/cs257/data/games1"

def grabDat(fileLoc):
    out = []
    headers = []
    with open(fileLoc, newline='',encoding='utf8') as data:
        reader = csv.reader(data)
        isFirst = 1
        isSecond = 0
        for row in reader:
            if isSecond:
                for i in row:
                    out.append([i])
                isSecond=0
            if isFirst:
                for i in row:
                    headers.append(i)
                isFirst = 0
                isSecond = 1
            else:
                for ind,i in enumerate(row):
                    out[ind].append(i)
    return out,headers


dat,headers = grabDat(filePath)

with open(outPath,'w',encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerows(dat)


i=1
idsNames = {}
for j in range(len(dat[i])):
    if(dat[i][j] not in idsNames):
        idsNames[dat[i][j]] = {'id':len(idsNames)}
newIds = []
for k in idsNames.keys():
    newIds.append([k,idsNames[k]['id']])
with open(f"/Users/thoma/cs257/cs257/data/{headers[i]}.csv",'w',encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerows(newIds)

# %%
flipped = list(zip(*newIds))

# %%
flipped[0][5]
# Out:
# 'Gloomhaven'

# %%
print(idsNames)
# Out:
# {'Terraforming Mars: Prelude': {'id': 0}, 'Brass: Birmingham': {'id': 1}, 'The Castles of Burgundy: Special Edition': {'id': 2}, 'Pandemic Legacy: Season 1': {'id': 3}, 'Ark Nova': {'id': 4}, 'Gloomhaven': {'id': 5}, 'Twilight Imperium: Fourth Edition': {'id': 6}, 'Dune: Imperium': {'id': 7}, 'Terraforming Mars': {'id': 8}, 'War of the Ring: Second Edition': {'id': 9}, 'Star Wars: Rebellion': {'id': 10}, 'Spirit Island: Jagged Earth': {'id': 11}, 'Spirit Island': {'id': 12}, 'Gloomhaven: Jaws of the Lion': {'id': 13}, 'Dune: Imperium - Uprising': {'id': 14}, 'Gaia Project': {'id': 15}, 'Spirit Island: Branch & Claw': {'id': 16}, 'Dune: Imperium - Rise of Ix': {'id': 17}, 'Twilight Struggle': {'id': 18}, 'Through the Ages: A New Story of Civilization': {'id': 19}, 'The Castles of Burgundy': {'id': 20}, 'Viticulture: Tuscany Essential Edition': {'id': 21}, 'Great Western Trail': {'id': 22}, 'Scythe': {'id': 23}, 'Eclipse: Second Dawn for the Galaxy': {'id': 24}, '7 Wonders Duel': {'id': 25}, 'Brass: Lancashire': {'id': 26}, 'Mage Knight: Ultimate Edition': {'id': 27}, 'Lost Ruins of Arnak: Expedition Leaders': {'id': 28}, 'Scythe: The Rise of Fenris': {'id': 29}, 'Nemesis': {'id': 30}, 'Frosthaven': {'id': 31}, 'Clank! Legacy: Acquisitions Incorporated': {'id': 32}, 'A Feast for Odin': {'id': 33}, 'Concordia': {'id': 34}, 'Wingspan: European Expansion': {'id': 35}, 'Wingspan: Oceania Expansion': {'id': 36}, 'Great Western Trail: Second Edition': {'id': 37}, 'Arkham Horror: The Card Game': {'id': 38}, 'Lost Ruins of Arnak': {'id': 39}, 'Root': {'id': 40}, 'Ark Nova: Marine Worlds': {'id': 41}, 'Too Many Bones': {'id': 42}, 'Terra Mystica': {'id': 43}, 'Wingspan': {'id': 44}, 'Terraforming Mars: Hellas & Elysium': {'id': 45}, 'Orléans': {'id': 46}, 'Mage Knight Board Game': {'id': 47}, 'Barrage': {'id': 48}, 'Sky Team': {'id': 49}, 'Dominion: Prosperity': {'id': 50}, 'The Crew: Mission Deep Sea': {'id': 51}, 'Everdell': {'id': 52}, 'Viticulture Essential Edition': {'id': 53}, 'The Lord of the Rings: Duel for Middle-earth': {'id': 54}, 'Lords of Waterdeep: Scoundrels of Skullport': {'id': 55}, 'Heat: Pedal to the Metal': {'id': 56}, 'Marvel Champions: The Card Game': {'id': 57}, 'Scythe: Invaders from Afar': {'id': 58}, 'Crokinole': {'id': 59}, 'Food Chain Magnate': {'id': 60}, 'Kanban EV': {'id': 61}, 'Pax Pamir: Second Edition': {'id': 62}, 'Underwater Cities': {'id': 63}, 'Hegemony: Lead Your Class to Victory': {'id': 64}, 'Puerto Rico': {'id': 65}, 'Cascadia': {'id': 66}, 'Cthulhu: Death May Die': {'id': 67}, 'Pandemic Legacy: Season 0': {'id': 68}, 'Root: The Riverfolk Expansion': {'id': 69}, 'Caverna: The Cave Farmers': {'id': 70}, 'Anachrony': {'id': 71}, 'Star Wars: Rebellion - Rise of the Empire': {'id': 72}, 'On Mars': {'id': 73}, 'Slay the Spire: The Board Game': {'id': 74}, 'Blood Rage': {'id': 75}, 'Agricola': {'id': 76}, 'Oathsworn: Into the Deepwood': {'id': 77}, 'Root: The Underworld Expansion': {'id': 78}, 'Sleeping Gods': {'id': 79}, 'Lisboa': {'id': 80}, 'Pandemic Legacy: Season 2': {'id': 81}, 'Age of Innovation': {'id': 82}, 'Obsession': {'id': 83}, 'Pandemic: On the Brink': {'id': 84}, 'A Feast for Odin: The Norwegians': {'id': 85}, 'Grand Austria Hotel': {'id': 86}, 'Mansions of Madness: Second Edition': {'id': 87}, "Tzolk'in: The Mayan Calendar": {'id': 88}, 'Power Grid': {'id': 89}, 'SETI: Search for Extraterrestrial Intelligence': {'id': 90}, 'Quacks': {'id': 91}, 'Clans of Caledonia': {'id': 92}, 'Le Havre': {'id': 93}, 'Maracaibo': {'id': 94}, 'Paladins of the West Kingdom': {'id': 95}, 'Dominion: Seaside': {'id': 96}, 'The Gallerist': {'id': 97}, 'Clank!: Catacombs': {'id': 98}, 'Star Wars: Imperial Assault': {'id': 99}, 'Android: Netrunner': {'id': 100}, 'Mechs vs. Minions': {'id': 101}, 'Agricola (Revised Edition)': {'id': 102}, 'The Crew: The Quest for Planet Nine': {'id': 103}, 'Kingdom Death: Monster': {'id': 104}, '7 Wonders Duel: Pantheon': {'id': 105}, 'Race for the Galaxy': {'id': 106}, 'Azul': ...

# %%
for i in range(len(headers))[:25]:
    if(i==1):
        continue
    ids = {}
    idsToNames = []
    for j in range(len(dat[i])):
        if(dat[i][j] not in ids):
            ids[dat[i][j]] = {'id':len(ids)}
        idsToNames.append([ids[dat[i][j]]['id'],idsNames[dat[1][j]]['id']])
    newIds = []
    for k in ids.keys():
        newIds.append([k,ids[k]['id']])
    with open(f"/Users/thoma/cs257/cs257/data/{headers[i]}.csv",'w',encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerows(newIds)
    with open(f'/Users/thoma/cs257/cs257/data/{headers[i]}_to_name.csv','w',encoding='utf-8') as g:
        writer = csv.writer(g)
        writer.writerows(idsToNames)
